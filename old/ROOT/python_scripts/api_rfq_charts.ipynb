# %%
import pandas as pd
import plotly.express as px

# %%
## RFQ Outrights ex histroy

# %%
df = pd.read_csv("/home/dilan/Tradefeedr-Documentation/modules/ROOT/examples/api_rfq/outrights/execution_history/raw/api_rfq_outrights_execution_history_ex1.csv")
df = df.set_index("Date")
df=df.groupby("Date").sum()
df
# Out:
#             TradeQuantity
# Date
# 2021-04-02   4.524456e+09
# 2021-04-05   3.826981e+09
# 2021-04-06   4.394817e+09
# 2021-04-07   4.018206e+09
# 2021-04-08   4.853294e+09
# ...                   ...
# 2021-06-24   3.504608e+09
# 2021-06-25   4.097295e+09
# 2021-06-28   3.985612e+09
# 2021-06-29   3.884694e+09
# 2021-06-30   3.859487e+09
#
# [64 rows x 1 columns]

# %%
fig = px.line(df,y ="TradeQuantity", title = "Daily Traded Volume")
fig

# %%
fig.write_image("/home/dilan/Tradefeedr-Documentation/modules/ROOT/images/api_rfq/outrights/execution_history/api_rfq_outrights_execution_history_ex1_fig.png")

# %%
## RFQ Swaps ex histroy

# %%
df = pd.read_csv("/home/dilan/Tradefeedr-Documentation/modules/ROOT/examples/api_rfq/swaps/execution_history/raw/api_rfq_swaps_execution_history_ex1.csv", index_col=0)
df.head()
# Out:
#             Account                TradeTime  Symbol TradeCcy Side  \
# Date
# 2021-04-05  Account  2021-04-05 07:49:12.138  AUDUSD      AUD   SB
# 2021-04-05  Account  2021-04-05 08:09:22.677  AUDUSD      AUD   BS
# 2021-04-05  Account  2021-04-05 08:52:17.548  AUDUSD      AUD   BS
# 2021-04-05  Account  2021-04-05 10:07:25.755  AUDUSD      AUD   SB
# 2021-04-05  Account  2021-04-05 10:23:34.337  AUDUSD      AUD   BS
#
#             NearTradeQuantity ProductType
# Date
# 2021-04-05       5.218147e+07        SWAP
# 2021-04-05       2.051308e+07        SWAP
# 2021-04-05       9.213931e+07        SWAP
# 2021-04-05       9.011011e+07        SWAP
# 2021-04-05       4.342239e+07        SWAP

# %%
fig = px.scatter(df,x="TradeTime" ,y ="NearTradeQuantity", color =  "Symbol", title = "NearTradeQuantity by TradeTime and Symbol")
fig

# %%
fig.write_image("/home/dilan/Tradefeedr-Documentation/modules/ROOT/images/api_rfq/swaps/execution_history/api_rfq_swaps_execution_history_ex1_fig.png")

# %%
outrights ex history
# Out:
#   Input In [9]
#     outrights ex history
#               ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv("/home/dilan/Tradefeedr-Documentation/modules/ROOT/examples/api_rfq/outrights/execution_stats/raw/api_rfq_outrights_execution_stats_ex3.csv", index_col=0)
df.head()
# Out:
#              TradeQuantityUSD  Symbol Side    Price  NumLPs  SecondBestPrice  \
# TradeID
# Trade_00001      1.105341e+08  EURUSD    B  1.17668       8         1.176684
# Trade_00026      1.155611e+08  AUDUSD    S  0.76060       7         0.760595
# Trade_00043      2.797803e+07  GBPUSD    S  1.38222       4         1.382086
# Trade_00044      1.486664e+08  GBPUSD    B  1.38289       7         1.383016
# Trade_00056      7.119764e+07  EURUSD    B  1.17814       4         1.178222
#
#               BestBid   BestAsk   TotalVolume
# TradeID
# Trade_00001  1.175895  1.176684  1.105341e+08
# Trade_00026  0.760595  0.762156  1.155611e+08
# Trade_00043  1.382086  1.383050  2.797803e+07
# Trade_00044  1.381255  1.383016  1.486664e+08
# Trade_00056  1.177477  1.178222  7.119764e+07

# %%
fig= px.scatter(df.head(1), y=["Price","SecondBestPrice"], title = "Outrights RFQ Price by TradeID")
fig

# %%
fig.write_image("/home/dilan/Tradefeedr-Documentation/modules/ROOT/images/api_rfq/outrights/execution_stats/api_rfq_outrights_execution_stats_ex3_fig.png")

# %%
ex 6

# %%
df = pd.read_csv("/home/dilan/Tradefeedr-Documentation/modules/ROOT/examples/api_rfq/outrights/execution_stats/raw/api_rfq_outrights_execution_stats_ex6.csv", index_col=0)
df.head()
# Out:
#       Symbol Side  TradeQuantityUSD     Price
# LP
# LP_1  EURUSD    B        10000000.0  1.205711
# LP_1  EURUSD    B        20000000.0  1.206137
# LP_1  EURUSD    B        40000000.0  1.200316
# LP_1  EURUSD    B        50000000.0  1.206444
# LP_1  EURUSD    B        60000000.0  1.195639

# %%
fig=px.scatter(df, x="TradeQuantityUSD", y ="Price", title = "Scatter plot of Price and TradeQuantityUSD", size="TradeQuantityUSD")
fig

# %%
fig.write_image("/home/dilan/Tradefeedr-Documentation/modules/ROOT/images/api_rfq/outrights/execution_stats/api_rfq_outrights_execution_stats_ex6_fig.png")

# %%
ex7

# %%
df = pd.read_csv("/home/dilan/Tradefeedr-Documentation/modules/ROOT/examples/api_rfq/outrights/execution_stats/raw/api_rfq_outrights_execution_stats_ex7.csv", index_col=0)
df.head()
# Out:
#       Symbol Side  TradeQuantityUSD  MinPrice  MaxPrice     Price  Count  \
# LP
# LP_1  EURUSD    B      3.240490e+07   1.18678   1.22152  1.204012     17
# LP_1  EURUSD    B      6.085842e+07   1.17618   1.22610  1.202969     24
# LP_1  EURUSD    B      8.931194e+07   1.18877   1.22051  1.201606      4
# LP_1  EURUSD    B      1.177655e+08   1.18574   1.22162  1.200974     10
# LP_1  EURUSD    B      1.462190e+08   1.19056   1.22578  1.208108     11
#
#        TotalVolume  AvgNumLPs
# LP
# LP_1  4.143996e+08   6.411765
# LP_1  1.512818e+09   6.250000
# LP_1  3.962722e+08   6.500000
# LP_1  1.210875e+09   6.000000
# LP_1  1.579239e+09   5.909091

# %%
fig =px.bar(df, x= "TradeQuantityUSD", y= "Count", title = "TradeQuantityUSD frequency plot")
fig

# %%
fig.write_image("/home/dilan/Tradefeedr-Documentation/modules/ROOT/images/api_rfq/outrights/execution_stats/api_rfq_outrights_execution_stats_ex7_fig.png")

# %%
ex11

# %%
df = pd.read_csv("/home/dilan/Tradefeedr-Documentation/modules/ROOT/examples/api_rfq/outrights/execution_stats/raw/api_rfq_outrights_execution_stats_ex11.csv", index_col=0)
df.head()
# Out:
#       Symbol Side  TradeQuantityUSD     Price  Price_Pct25  Price_Pct50  \
# LP
# LP_1  AUDUSD    B      6.616962e+08  0.767687     0.758723     0.768760
# LP_1  AUDUSD    S      3.190422e+08  0.763399     0.759373     0.765155
# LP_1  EURUSD    B      1.041191e+09  1.203817     1.191680     1.202840
# LP_1  EURUSD    S      4.769489e+08  1.202087     1.190195     1.194490
# LP_1  GBPUSD    B      1.818280e+09  1.405739     1.388800     1.414260
#
#       Price_Pct75  Price_Pct90  Price_Pct100
# LP
# LP_1     0.774950     0.775438       0.77920
# LP_1     0.770160     0.770970       0.77151
# LP_1     1.218355     1.221620       1.22293
# LP_1     1.213865     1.219850       1.22603
# LP_1     1.419342     1.420985       1.42116

# %%
fig =px.scatter(df[(df.Symbol == "EURUSD") & (df.Side == "B")], y= ["Price","Price_Pct25","Price_Pct50","Price_Pct75","Price_Pct90","Price_Pct100"], 
          title  ="Price Percentiles by LP" )
fig

# %%
fig.write_image("/home/dilan/Tradefeedr-Documentation/modules/ROOT/images/api_rfq/outrights/execution_stats/api_rfq_outrights_execution_stats_ex11_fig.png")

# %%
Swaps ex stats

# %%
df = pd.read_csv("/home/dilan/Tradefeedr-Documentation/modules/ROOT/examples/api_rfq/swaps/execution_stats/raw/api_rfq_swaps_execution_stats_ex1.csv", index_col=0)
df = df.groupby("LP").sum()
df = df.sort_values(by="NearTradeQuantity", ascending=False)

# %%
fig= px.bar(df.head(), y="NearTradeQuantity", title = "Swaps RFQ TradeQuantity by LP")
fig

# %%
fig.write_image("/home/dilan/Tradefeedr-Documentation/modules/ROOT/images/api_rfq/swaps/execution_stats/api_rfq_swaps_execution_stats_ex1_fig.png")

# %%
rfq oppurinity reprot

# %%
df = pd.read_csv("/home/dilan/Tradefeedr-Documentation/modules/ROOT/examples/api_rfq/outrights/opportunity_report/raw/api_rfq_outrights_opportunity_report_ex1.csv", index_col=0)
df.head()
# Out:
#      OutCome  Symbol Side  TradeQuantity TradeCcy                TradeTime  \
# LP
# LP_1    LOST  AUDUSD    S   1.983429e+08      AUD  2021-04-02 10:54:05.577
# LP_1     WON  AUDUSD    S   1.518044e+08      AUD  2021-04-02 12:12:06.090
# LP_1    LOST  AUDUSD    B   1.541480e+07      AUD  2021-04-02 14:30:50.714
# LP_1     WON  AUDUSD    S   1.739897e+08      AUD  2021-04-02 15:01:37.076
# LP_1    LOST  AUDUSD    B   1.121842e+08      AUD  2021-04-02 15:14:59.875
#
#       AllInRate  PriceShown ProductType  MissedByPIPS  MissedByUSDPM
# LP
# LP_1    0.76086    0.760451        SPOT      4.092891     537.929526
# LP_1    0.76060    0.760600        SPOT     -0.000000      -0.000000
# LP_1    0.76049    0.760618        SPOT      1.284722     168.933490
# LP_1    0.75967    0.759670        SPOT     -0.000000      -0.000000
# LP_1    0.76111    0.761569        SPOT      4.590540     603.137489

# %%
fig= px.scatter(df[df.Symbol=="AUDUSD"], x = "TradeTime", y = ["PriceShown"], color = "OutCome", title ="Scatter plot of AUDUSD PriceShown by OutCome")
fig
# Out:
# <div>                            <div id="001838e4-43a8-49c9-a365-4e63f529ca1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("001838e4-43a8-49c9-a365-4e63f529ca1b")) {                    Plotly.newPlot(                        "001838e4-43a8-49c9-a365-4e63f529ca1b",                        [{"hovertemplate":"OutCome=LOST<br>TradeTime=%{x}<br>value=%{y}<extra></extra>","legendgroup":"LOST","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"LOST","orientation":"v","showlegend":true,"x":["2021-04-02 10:54:05.577","2021-04-02 14:30:50.714","2021-04-02 15:14:59.875","2021-04-02 15:14:59.875","2021-04-02 15:14:59.875","2021-04-02 15:14:59.875","2021-04-02 15:14:59.875","2021-04-02 15:14:59.875","2021-04-05 13:50:13.258","2021-04-05 14
# ...

# %%
fig.write_image("/home/dilan/Tradefeedr-Documentation/modules/ROOT/images/api_rfq/outrights/opportunity_report/api_rfq_outrights_opportunity_report_ex1_fig.png")

# %%
EX3

# %%
df = pd.read_csv("/home/dilan/Tradefeedr-Documentation/modules/ROOT/examples/api_rfq/outrights/opportunity_report/raw/api_rfq_outrights_opportunity_report_ex3.csv", index_col=0)
df = df[df.TradeCcy=="AUD"].head(30)

# %%
fig=px.scatter(df, x = "TradeTime" , y ="MissedByPIPS", title ="Select Losing RFQs only TradeCcy:AUD")
fig

# %%
fig.write_image("/home/dilan/Tradefeedr-Documentation/modules/ROOT/images/api_rfq/outrights/opportunity_report/api_rfq_outrights_opportunity_report_ex3_fig.png")

# %%
rfq oppurinity reprot Swaps

# %%
df = pd.read_csv("/home/dilan/Tradefeedr-Documentation/modules/ROOT/examples/api_rfq/swaps/opportunity_report/raw/api_rfq_swaps_opportunity_report_ex1.csv", index_col=0)
df.head()
# Out:
#      OutCome  Symbol Side  NearTradeQuantity  FarTradeQuantity TradeCcy  \
# LP
# LP_1     WON  AUDUSD   SB       5.218147e+07      5.218147e+07      AUD
# LP_1    LOST  AUDUSD   BS       2.051308e+07      2.051308e+07      AUD
# LP_1    LOST  AUDUSD   BS       4.342239e+07      4.342239e+07      AUD
# LP_1    LOST  AUDUSD   SB       1.178356e+08      1.178356e+08      AUD
# LP_1    LOST  AUDUSD   BS       5.301109e+07      5.301109e+07      AUD
#
#                     TradeTime  FarPrice  NearPrice  NearForwardPoints  \
# LP
# LP_1  2021-04-05 07:49:12.138  0.761130   0.760830               -1.0
# LP_1  2021-04-05 08:09:22.677  0.761745   0.761845                1.0
# LP_1  2021-04-05 10:23:34.337  0.762260   0.762360                1.0
# LP_1  2021-04-05 12:58:13.984  0.763790   0.763490               -1.0
# LP_1  2021-04-05 17:39:56.495  0.765255   0.765355                1.0
#
#       FarForwardPoints  NearPriceShown  FarPriceShown  NearFPShown  \
# LP
# ...

# %%
fig= px.scatter(df[df.Symbol=="AUDUSD"], x = "TradeTime", y = ["NearPriceShown"], color = "OutCome", title ="Scatter plot of AUDUSD NearPriceShown by OutCome")
fig

# %%
fig.write_image("/home/dilan/Tradefeedr-Documentation/modules/ROOT/images/api_rfq/swaps/opportunity_report/api_rfq_swaps_opportunity_report_ex1_fig.png")

# %%
ex3

# %%
df = pd.read_csv("/home/dilan/Tradefeedr-Documentation/modules/ROOT/examples/api_rfq/swaps/opportunity_report/raw/api_rfq_swaps_opportunity_report_ex3.csv", index_col=0)
df.head()
# Out:
#      OutCome TradeCcy Side                TradeTime ProductType  NearPrice  \
# LP
# LP_1    LOST      AUD   BS  2021-04-05 08:09:22.677        SWAP   0.761845
# LP_1    LOST      AUD   BS  2021-04-05 10:23:34.337        SWAP   0.762360
# LP_1    LOST      AUD   SB  2021-04-05 12:58:13.984        SWAP   0.763490
# LP_1    LOST      AUD   BS  2021-04-05 17:39:56.495        SWAP   0.765355
# LP_1    LOST      AUD   BS  2021-04-05 22:00:23.331        SWAP   0.765215
#
#       NearPriceShown  FarPrice  FarPriceShown  MissedFP
# LP
# LP_1        0.762062  0.761745       0.761525       0.0
# LP_1        0.762602  0.762260       0.761996       0.0
# LP_1        0.762662  0.763790       0.764626       0.0
# LP_1        0.765602  0.765255       0.764743       0.0
# LP_1        0.766809  0.765115       0.763898       0.0

# %%
fig=px.scatter(df[df.TradeCcy=="AUD"], x = "TradeTime" , y =["NearPrice","NearPriceShown","FarPrice","FarPriceShown"], title ="Select Losing RFQs only TradeCcy:AUD")
fig

# %%
fig.write_image("/home/dilan/Tradefeedr-Documentation/modules/ROOT/images/api_rfq/swaps/opportunity_report/api_rfq_swaps_opportunity_report_ex3_fig.png")

# %%
RFQ OUTRIGHTS participation-report

# %%
EX1

# %%
df = pd.read_csv("/home/dilan/Tradefeedr-Documentation/modules/ROOT/examples/api_rfq/outrights/participation_report/raw/api_rfq_outrights_participation_report_ex1.csv", index_col=0)
df.head()
# Out:
#       NumberOfParticipations  NumberOfWins  ExpectedWins  ActualWinRatio  \
# LP
# LP_1                    2394           676    402.240476       28.237260
# LP_2                    2340           612    390.440476       26.153846
# LP_3                    2305           509    383.533333       22.082430
# LP_4                    2297           401    382.907143       17.457553
# LP_5                    2284           337    378.764286       14.754816
#
#       ExpectedWinRatio  VolumeParticipated     VolumeWon  ExpectedWinVolume  \
# LP
# LP_1         16.802025        2.215613e+11  6.424204e+10       3.722587e+10
# LP_2         16.685490        2.163640e+11  5.478547e+10       3.625677e+10
# LP_3         16.639190        2.098501e+11  4.715341e+10       3.464388e+10
# LP_4         16.669880        2.124722e+11  3.761392e+10       3.543312e+10
# LP_5         16.583375        2.079086e+11  2.814865e+10       3.447295e+10
#
# ...

# %%
fig = px.bar(df, y =["NumberOfParticipations","NumberOfWins","ExpectedWins"], barmode="group", title ="Number of Outright RFQs Won by LP")
fig
# Out:
# <div>                            <div id="2d97f3a5-56e6-43c2-a9fd-afc824d8d944" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d97f3a5-56e6-43c2-a9fd-afc824d8d944")) {                    Plotly.newPlot(                        "2d97f3a5-56e6-43c2-a9fd-afc824d8d944",                        [{"alignmentgroup":"True","hovertemplate":"variable=NumberOfParticipations<br>LP=%{x}<br>value=%{y}<extra></extra>","legendgroup":"NumberOfParticipations","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"NumberOfParticipations","offsetgroup":"NumberOfParticipations","orientation":"v","showlegend":true,"textposition":"auto","x":["LP_1","LP_2","LP_3","LP_4","LP_5","LP_6","LP_7","LP_8"],"xaxis":"x","y":[2394.0,2340.0,2305.0,2297.0,2284.0,2231.0,2237.0,2229
# ...

# %%
fig.write_image("/home/dilan/Tradefeedr-Documentation/modules/ROOT/images/api_rfq/outrights/participation_report/api_rfq_outrights_participation_report_ex1_fig.png")

# %%
EX2

# %%
df = pd.read_csv("/home/dilan/Tradefeedr-Documentation/modules/ROOT/examples/api_rfq/outrights/participation_report/raw/api_rfq_outrights_participation_report_ex2.csv", index_col=0)
df.head()
# Out:
#       NumberOfParticipations  NumberOfWins  ExpectedWins  ActualWinRatio  \
# LP
# LP_1                    2394           676    402.240476       28.237260
# LP_2                    2340           612    390.440476       26.153846
# LP_3                    2305           509    383.533333       22.082430
# LP_4                    2297           401    382.907143       17.457553
# LP_5                    2284           337    378.764286       14.754816
#
#       ExpectedWinRatio  AverageRFQPanelSize  WinPerformanceScore
# LP
# LP_1         16.802025             6.295322            11.435235
# LP_2         16.685490             6.329915             9.468356
# LP_3         16.639190             6.347505             5.443239
# LP_4         16.669880             6.339573             0.787673
# LP_5         16.583375             6.361646            -1.828559

# %%
fig = px.bar(df, y =["ActualWinRatio","ExpectedWinRatio", "AverageRFQPanelSize","WinPerformanceScore"], barmode="group", title ="Hit Ratios by LP")
fig
# Out:
# <div>                            <div id="23f06651-604f-4464-8fa6-3ab04a23df06" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23f06651-604f-4464-8fa6-3ab04a23df06")) {                    Plotly.newPlot(                        "23f06651-604f-4464-8fa6-3ab04a23df06",                        [{"alignmentgroup":"True","hovertemplate":"variable=ActualWinRatio<br>LP=%{x}<br>value=%{y}<extra></extra>","legendgroup":"ActualWinRatio","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"ActualWinRatio","offsetgroup":"ActualWinRatio","orientation":"v","showlegend":true,"textposition":"auto","x":["LP_1","LP_2","LP_3","LP_4","LP_5","LP_6","LP_7","LP_8"],"xaxis":"x","y":[28.23725981620718,26.15384615384616,22.0824295010846,17.457553330430997,14.7548161120
# ...

# %%
fig.write_image("/home/dilan/Tradefeedr-Documentation/modules/ROOT/images/api_rfq/outrights/participation_report/api_rfq_outrights_participation_report_ex2_fig.png")

# %%
EX3

# %%
df = pd.read_csv("/home/dilan/Tradefeedr-Documentation/modules/ROOT/examples/api_rfq/outrights/participation_report/raw/api_rfq_outrights_participation_report_ex3.csv", index_col=0)
df.head()
# Out:
#       VolumeParticipated     VolumeWon  ExpectedWinVolume  \
# LP
# LP_1        2.215613e+11  6.424204e+10       3.722587e+10
# LP_2        2.163640e+11  5.478547e+10       3.625677e+10
# LP_3        2.098501e+11  4.715341e+10       3.464388e+10
# LP_4        2.124722e+11  3.761392e+10       3.543312e+10
# LP_5        2.079086e+11  2.814865e+10       3.447295e+10
#
#       ActualVolumeWinRatio  ExpectedVolumeWinRatio  AverageRFQPanelSize  \
# LP
# LP_1             28.995153               16.801610             6.295322
# LP_2             25.320972               16.757301             6.329915
# LP_3             22.470043               16.508870             6.347505
# LP_4             17.702983               16.676591             6.339573
# LP_5             13.538958               16.580822             6.361646
#
#       VolumePerformanceScore
# LP
# LP_1               12.193543
# LP_2                8.563672
# LP_3                5.961173
# LP_4                1.026392
# ...

# %%
fig = px.bar(df, y =["ActualVolumeWinRatio","ExpectedVolumeWinRatio", "AverageRFQPanelSize","VolumePerformanceScore"], barmode="group", title ="Volume metrics by LP")
fig
# Out:
# <div>                            <div id="9b8b6231-3392-46ed-a188-d419dd837b49" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b8b6231-3392-46ed-a188-d419dd837b49")) {                    Plotly.newPlot(                        "9b8b6231-3392-46ed-a188-d419dd837b49",                        [{"alignmentgroup":"True","hovertemplate":"variable=ActualVolumeWinRatio<br>LP=%{x}<br>value=%{y}<extra></extra>","legendgroup":"ActualVolumeWinRatio","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"ActualVolumeWinRatio","offsetgroup":"ActualVolumeWinRatio","orientation":"v","showlegend":true,"textposition":"auto","x":["LP_1","LP_2","LP_3","LP_4","LP_5","LP_6","LP_7","LP_8"],"xaxis":"x","y":[28.995152670651255,25.32097221163196,22.47004263866961,17.702
# ...

# %%
fig.write_image("/home/dilan/Tradefeedr-Documentation/modules/ROOT/images/api_rfq/outrights/participation_report/api_rfq_outrights_participation_report_ex3_fig.png")

# %% [markdown]
# EX4

# %%
df = pd.read_csv("/home/dilan/Tradefeedr-Documentation/modules/ROOT/examples/api_rfq/outrights/participation_report/raw/api_rfq_outrights_participation_report_ex4.csv", index_col=0)
df.head()
# Out:
#       NumberOfParticipations  NumberOfWins  VolumeParticipated     VolumeWon  \
# LP
# LP_1                    2394           676        2.215613e+11  6.424204e+10
# LP_2                    2340           612        2.163640e+11  5.478547e+10
# LP_3                    2305           509        2.098501e+11  4.715341e+10
# LP_4                    2297           401        2.124722e+11  3.761392e+10
# LP_5                    2284           337        2.079086e+11  2.814865e+10
#
#       ActualWinRatio  ActualVolumeWinRatio
# LP
# LP_1       28.237260             28.995153
# LP_2       26.153846             25.320972
# LP_3       22.082430             22.470043
# LP_4       17.457553             17.702983
# LP_5       14.754816             13.538958

# %%
fig = px.bar(df, y =["ActualWinRatio","ActualVolumeWinRatio"], barmode="group", title ="Comparing WinRatios")
fig
# Out:
# <div>                            <div id="78a3bb75-dd0d-4cf2-bb91-af7a259bf4ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78a3bb75-dd0d-4cf2-bb91-af7a259bf4ec")) {                    Plotly.newPlot(                        "78a3bb75-dd0d-4cf2-bb91-af7a259bf4ec",                        [{"alignmentgroup":"True","hovertemplate":"variable=ActualWinRatio<br>LP=%{x}<br>value=%{y}<extra></extra>","legendgroup":"ActualWinRatio","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"ActualWinRatio","offsetgroup":"ActualWinRatio","orientation":"v","showlegend":true,"textposition":"auto","x":["LP_1","LP_2","LP_3","LP_4","LP_5","LP_6","LP_7","LP_8"],"xaxis":"x","y":[28.23725981620718,26.15384615384616,22.0824295010846,17.457553330430997,14.7548161120
# ...

# %%
fig.write_image("/home/dilan/Tradefeedr-Documentation/modules/ROOT/images/api_rfq/outrights/participation_report/api_rfq_outrights_participation_report_ex4_fig.png")
